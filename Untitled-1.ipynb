# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
from ml.management.commands.ml_train import fetch_data

fetch_data()
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-2-7123814a1310> in <module>
#       1 import os
#       2 os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
# ----> 3 from ml.management.commands.ml_train import fetch_data
#       4
#       5 fetch_data()
#
# ~/tournesol-backend/ml/management/commands/ml_train.py in <module>
#       1 from django.core.management.base import BaseCommand, CommandError
#       2
# ----> 3 from tournesol.models import Comparison
#       4 from settings.settings import VIDEO_FIELDS
#       5
#
# ~/tournesol-backend/tournesol/models/__init__.py in <module>
# ----> 1 from .video import *
#
# ~/tournesol-backend/tournesol/models/video.py in <module>
#      14 from tqdm.auto import tqdm
#      15
# ---> 16 from core.models import User
# ...
